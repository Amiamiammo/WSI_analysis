# %%
from classification_task import run_classification_task

# %%
pickle_file_dino = "embeddings_patch_library/dino.pkl"
pickle_file_resnet50 = "embeddings_patch_library/resnet50.pkl"

# %%
print("---- start classification for vit extracted features ---- ")
run_classification_task(pickle_file_dino)

# %%
print("---- start classification for resnet50 extracted features ---- ")
run_classification_task(pickle_file_resnet50)
